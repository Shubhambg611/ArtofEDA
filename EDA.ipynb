# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv("/mnt/shubham SSD2/ArtofEDA/covid_women.csv")

# %%
data
# Out:
#        OSF_ID  Maternal_Age    Household_Income    Maternal_Education  \
# 0           1          38.3           $200,000+        Masters degree
# 1           2          34.6           $200,000+  Undergraduate degree
# 2           3          34.3  $100,000 -$124,999  Undergraduate degree
# 3           4          28.8  $100,000 -$124,999        Masters degree
# 4           5          36.5     $40,000-$69,999  Undergraduate degree
# ...       ...           ...                 ...                   ...
# 10767   10768          38.3  $100,000 -$124,999  Undergraduate degree
# 10768   10769          29.9  $125,000- $149,999  Undergraduate degree
# 10769   10770          27.7    $20,000- $39,999  College/trade school
# 10770   10771          23.0    $20,000- $39,999  College/trade school
# 10771   10772          34.6     $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                       9.0            13.0
# ...

# %%
data.describe()
# Out:
#              OSF_ID  Maternal_Age  Edinburgh_Postnatal_Depression_Scale  \
# count  10772.000000  10661.000000                           9598.000000
# mean    5386.500000     31.844602                             10.194832
# std     3109.752884      4.422368                              5.505230
# min        1.000000     17.000000                              0.000000
# 25%     2693.750000     28.900000                              6.000000
# 50%     5386.500000     31.800000                             10.000000
# 75%     8079.250000     34.800000                             14.000000
# max    10772.000000     49.700000                             30.000000
#
#        PROMIS_Anxiety  Gestational_Age_At_Birth  Birth_Length  Birth_Weight  \
# count     9566.000000               6734.000000   5480.000000   6078.000000
# mean        18.677713                 39.342241     50.502504   3412.175058
# std          6.084313                  1.612483      4.445347    538.695046
# ...

# %%
data.columns
# Out:
# Index(['OSF_ID', 'Maternal_Age', 'Household_Income', 'Maternal_Education',
#        'Edinburgh_Postnatal_Depression_Scale', 'PROMIS_Anxiety',
#        'Gestational_Age_At_Birth',
#        'Delivery_Date(converted to month and year)', 'Birth_Length',
#        'Birth_Weight', 'Delivery_Mode', 'NICU_Stay', 'Language',
#        'Threaten_Life', 'Threaten_Baby_Danger', 'Threaten_Baby_Harm'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# OSF_ID                                           0
# Maternal_Age                                   111
# Household_Income                               251
# Maternal_Education                             177
# Edinburgh_Postnatal_Depression_Scale          1174
# PROMIS_Anxiety                                1206
# Gestational_Age_At_Birth                      4038
# Delivery_Date(converted to month and year)    4039
# Birth_Length                                  5292
# Birth_Weight                                  4694
# Delivery_Mode                                 5235
# NICU_Stay                                     5238
# Language                                         0
# Threaten_Life                                  896
# Threaten_Baby_Danger                           904
# Threaten_Baby_Harm                             892
# dtype: int64

# %%
data.shape
# Out:
# (10772, 16)

# %%
data = data.drop(columns=['OSF_ID','Language'])

# %%
data.head()
# Out:
#    Maternal_Age    Household_Income    Maternal_Education  \
# 0          38.3           $200,000+        Masters degree
# 1          34.6           $200,000+  Undergraduate degree
# 2          34.3  $100,000 -$124,999  Undergraduate degree
# 3          28.8  $100,000 -$124,999        Masters degree
# 4          36.5     $40,000-$69,999  Undergraduate degree
#
#    Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                   9.0            13.0
# 1                                   4.0            17.0
# 2                                   NaN             NaN
# 3                                   9.0            20.0
# 4                                  14.0            20.0
#
#    Gestational_Age_At_Birth Delivery_Date(converted to month and year)  \
# 0                     39.71                                    Dec2020
# 1                       NaN                                        NaN
# ...

# %%
data.isna()
# Out:
#        Maternal_Age  Household_Income  Maternal_Education  \
# 0             False             False               False
# 1             False             False               False
# 2             False             False               False
# 3             False             False               False
# 4             False             False               False
# ...             ...               ...                 ...
# 10767         False             False               False
# 10768         False             False               False
# 10769         False             False               False
# 10770         False             False               False
# 10771         False             False               False
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                     False           False
# 1                                     False           False
# 2                                      True            True
# ...

# %%
rows_drop = (data['PROMIS_Anxiety'].isnull()) & (data['Delivery_Date(converted to month and year)'].isnull()) & (data['Threaten_Life']== ' ') & (data['Threaten_Baby_Danger']==' ') & (data['Threaten_Baby_Harm']==' ').index

# %%
rows_drop
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10767    False
# 10768    False
# 10769    False
# 10770    False
# 10771    False
# Length: 10772, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 43

# %%
data = data.drop_duplicates()

# %%
data.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of        Maternal_Age    Household_Income    Maternal_Education  \
# 0              38.3           $200,000+        Masters degree
# 1              34.6           $200,000+  Undergraduate degree
# 2              34.3  $100,000 -$124,999  Undergraduate degree
# 3              28.8  $100,000 -$124,999        Masters degree
# 4              36.5     $40,000-$69,999  Undergraduate degree
# ...             ...                 ...                   ...
# 10767          38.3  $100,000 -$124,999  Undergraduate degree
# 10768          29.9  $125,000- $149,999  Undergraduate degree
# 10769          27.7    $20,000- $39,999  College/trade school
# 10770          23.0    $20,000- $39,999  College/trade school
# 10771          34.6     $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                       9.0            13.0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Maternal_Age                                    94
# Household_Income                               234
# Maternal_Education                             160
# Edinburgh_Postnatal_Depression_Scale          1131
# PROMIS_Anxiety                                1163
# Gestational_Age_At_Birth                      3995
# Delivery_Date(converted to month and year)    3996
# Birth_Length                                  5249
# Birth_Weight                                  4651
# Delivery_Mode                                 5192
# NICU_Stay                                     5195
# Threaten_Life                                  853
# Threaten_Baby_Danger                           861
# Threaten_Baby_Harm                             849
# dtype: int64

# %%
data.describe()
# Out:
#        Maternal_Age  Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# count  10635.000000                           9598.000000     9566.000000
# mean      31.849788                             10.194832       18.677713
# std        4.423604                              5.505230        6.084313
# min       17.000000                              0.000000        7.000000
# 25%       28.900000                              6.000000       14.000000
# 50%       31.800000                             10.000000       19.000000
# 75%       34.800000                             14.000000       23.000000
# max       49.700000                             30.000000       35.000000
#
#        Gestational_Age_At_Birth  Birth_Length  Birth_Weight  Threaten_Life  \
# count               6734.000000   5480.000000   6078.000000    9876.000000
# mean                  39.342241     50.502504   3412.175058      42.342041
# std                    1.612483      4.445347    538.695046      25.640246
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10729 entries, 0 to 10771
# Data columns (total 14 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Maternal_Age                                10635 non-null  float64
#  1   Household_Income                            10495 non-null  object
#  2   Maternal_Education                          10569 non-null  object
#  3   Edinburgh_Postnatal_Depression_Scale        9598 non-null   float64
#  4   PROMIS_Anxiety                              9566 non-null   float64
#  5   Gestational_Age_At_Birth                    6734 non-null   float64
#  6   Delivery_Date(converted to month and year)  6733 non-null   object
#  7   Birth_Length                                5480 non-null   float64
#  8   Birth_Weight                                6078 non-null   float64
# ...

# %%
# lets plot numerical graphs 

numerical_data = data.select_dtypes(include=['number'])

# %%
numerical_data
# Out:
#        Maternal_Age  Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0              38.3                                   9.0            13.0
# 1              34.6                                   4.0            17.0
# 2              34.3                                   NaN             NaN
# 3              28.8                                   9.0            20.0
# 4              36.5                                  14.0            20.0
# ...             ...                                   ...             ...
# 10767          38.3                                  10.0            18.0
# 10768          29.9                                   NaN             NaN
# 10769          27.7                                   4.0            15.0
# 10770          23.0                                  12.0            19.0
# 10771          34.6                                  18.0            30.0
#
#        Gestational_Age_At_Birth  Birth_Length  Birth_Weight  Threaten_Life  \
# ...

# %%
fig , axs=plt.subplots(2,3, figsize=(15,10))
axs = axs.flatten()
for i, col in enumerate(numerical_data.columns):
    if i<6:
        sns.boxenplot(x = numerical_data[col],ax=axs[i])

# %%
fig, axs = plt.subplots(2,3 ,figsize=(15,10))
axs = axs.flatten()

for i,col in enumerate(numerical_data.columns):
    if i<6:
        sns.kdeplot(data=numerical_data[col],ax=axs[i])
        axs[i].set_title(col)
    
plt.tight_layout()
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10729 entries, 0 to 10771
# Data columns (total 14 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Maternal_Age                                10635 non-null  float64
#  1   Household_Income                            10495 non-null  object
#  2   Maternal_Education                          10569 non-null  object
#  3   Edinburgh_Postnatal_Depression_Scale        9598 non-null   float64
#  4   PROMIS_Anxiety                              9566 non-null   float64
#  5   Gestational_Age_At_Birth                    6734 non-null   float64
#  6   Delivery_Date(converted to month and year)  6733 non-null   object
#  7   Birth_Length                                5480 non-null   float64
#  8   Birth_Weight                                6078 non-null   float64
# ...

# %%
data
# Out:
#        Maternal_Age    Household_Income    Maternal_Education  \
# 0              38.3           $200,000+        Masters degree
# 1              34.6           $200,000+  Undergraduate degree
# 2              34.3  $100,000 -$124,999  Undergraduate degree
# 3              28.8  $100,000 -$124,999        Masters degree
# 4              36.5     $40,000-$69,999  Undergraduate degree
# ...             ...                 ...                   ...
# 10767          38.3  $100,000 -$124,999  Undergraduate degree
# 10768          29.9  $125,000- $149,999  Undergraduate degree
# 10769          27.7    $20,000- $39,999  College/trade school
# 10770          23.0    $20,000- $39,999  College/trade school
# 10771          34.6     $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                       9.0            13.0
# 1                                       4.0            17.0
# ...

# %%
print(data['Household_Income'].value_counts())
# Out:
# $70,000-$99,999        2087
# $100,000 -$124,999     1951
# $40,000-$69,999        1425
# $125,000- $149,999     1362
# $150,000 - $174,999    1138
# $200,000+              1008
# $175,000- $199,999      655
# $20,000- $39,999        609
# Less than $20, 000      260
# Name: Household_Income, dtype: int64

# %%
print(data['Maternal_Education'].value_counts())
# Out:
# Undergraduate degree             4112
# College/trade school             2743
# Masters degree                   1888
# High school diploma               898
# Doctoral Degree                   786
# Less than high school diploma     142
# Name: Maternal_Education, dtype: int64

# %%
print(data['Delivery_Mode'].value_counts())
# Out:
# Vaginally                        3904
# Caesarean-section (c-section)    1633
# Name: Delivery_Mode, dtype: int64

# %%
print(data['NICU_Stay'].value_counts())
# Out:
# No     4986
# Yes     548
# Name: NICU_Stay, dtype: int64

# %%
(data['Threaten_Life']).info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 10729 entries, 0 to 10771
# Series name: Threaten_Life
# Non-Null Count  Dtype
# --------------  -----
# 9876 non-null   float64
# dtypes: float64(1)
# memory usage: 167.6 KB

# %%
print(data['Threaten_Life'].value_counts())
# Out:
# 50.0    819
# 0.0     493
# 49.0    279
# 48.0    274
# 47.0    222
#        ...
# 84.0     20
# 86.0     19
# 89.0     18
# 88.0     14
# 87.0     12
# Name: Threaten_Life, Length: 101, dtype: int64

# %%
data['Threaten_Life'].isna().value_counts()
# Out:
# False    9876
# True      853
# Name: Threaten_Life, dtype: int64

# %%
data['Threaten_Life']
# Out:
# 0         2.0
# 1         2.0
# 2         NaN
# 3        53.0
# 4        23.0
#          ...
# 10767    54.0
# 10768     NaN
# 10769    21.0
# 10770    65.0
# 10771    84.0
# Name: Threaten_Life, Length: 10729, dtype: float64

# %%
data['Threaten_Life'] = data['Threaten_Life'].replace('', np.nan)  # Convert empty strings to NaN
data['Threaten_Life'] = data['Threaten_Life'].fillna(-1).astype(int)

# %%
data['Threaten_Life'].isna().sum()
# Out:
# 0

# %%
data['Threaten_Baby_Danger'].isna().sum()
# Out:
# 861

# %%
data['Threaten_Baby_Danger'] = data['Threaten_Baby_Danger'].replace('',np.nan)
data['Threaten_Baby_Danger'] = data['Threaten_Baby_Danger'].fillna(-1).astype(int)
print(data['Threaten_Baby_Danger'].isna().value_counts())
# Out:
# False    10729
# Name: Threaten_Baby_Danger, dtype: int64

# %%
data['Threaten_Baby_Harm'] = data['Threaten_Baby_Harm'].replace('',np.nan)
data['Threaten_Baby_Harm'] = data['Threaten_Baby_Harm'].fillna(-1).astype(int)
print(data['Threaten_Baby_Harm'].isna().sum())
# Out:
# 0

# %%
data
# Out:
#        Maternal_Age    Household_Income    Maternal_Education  \
# 0              38.3           $200,000+        Masters degree
# 1              34.6           $200,000+  Undergraduate degree
# 2              34.3  $100,000 -$124,999  Undergraduate degree
# 3              28.8  $100,000 -$124,999        Masters degree
# 4              36.5     $40,000-$69,999  Undergraduate degree
# ...             ...                 ...                   ...
# 10767          38.3  $100,000 -$124,999  Undergraduate degree
# 10768          29.9  $125,000- $149,999  Undergraduate degree
# 10769          27.7    $20,000- $39,999  College/trade school
# 10770          23.0    $20,000- $39,999  College/trade school
# 10771          34.6     $70,000-$99,999        Masters degree
#
#        Edinburgh_Postnatal_Depression_Scale  PROMIS_Anxiety  \
# 0                                       9.0            13.0
# 1                                       4.0            17.0
# ...

# %%
fig, axs = plt.subplots(1,3, figsize=(15,10))
axs = axs.flatten()

columns = ['Threaten_Baby_Danger', 'Threaten_Life', 'Threaten_Baby_Harm']

for i,col in enumerate(columns):
        sns.kdeplot(data = data[col],ax=axs[i])
        axs[i].set_title(col)

plt.tight_layout()
plt.show()

# %%
data.isna().sum()
# Out:
# Maternal_Age                                    94
# Household_Income                               234
# Maternal_Education                             160
# Edinburgh_Postnatal_Depression_Scale          1131
# PROMIS_Anxiety                                1163
# Gestational_Age_At_Birth                      3995
# Delivery_Date(converted to month and year)    3996
# Birth_Length                                  5249
# Birth_Weight                                  4651
# Delivery_Mode                                 5192
# NICU_Stay                                     5195
# Threaten_Life                                    0
# Threaten_Baby_Danger                             0
# Threaten_Baby_Harm                               0
# dtype: int64

# %% [markdown]
# # BIVARIAT ANALYSIS
